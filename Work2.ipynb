# %%
import pandas as pd
# בעמודות null לצורך הוספת import numpy as np ניתן להשתמש ב-בסיפריית

# %%
Data = {'ID':pd.Series([123,122,125,126,127,128,130])
       ,'Name':pd.Series(["Abigail","Dor","Lotem","Daniel","Mohamad","Aya","Dana"])
       ,'Country':pd.Series(["Israel","USA","Israel","USA","Israel","France"])
       ,'Score':pd.Series([99,67,98,87,97,79,56])
       }

Data_Frame = pd.DataFrame(Data)

# %%
Data_Frame.head() # לא כמו הדפסה רגילה
# Out:
#     ID     Name Country  Score
# 0  123  Abigail  Israel     99
# 1  122      Dor     USA     67
# 2  125    Lotem  Israel     98
# 3  126   Daniel     USA     87
# 4  127  Mohamad  Israel     97

# %%
Data_Frame[0:3]
# Out:
#     ID     Name Country  Score
# 0  123  Abigail  Israel     99
# 1  122      Dor     USA     67
# 2  125    Lotem  Israel     98

# %%
Data_Frame.describe()
# Out:
#                ID      Score
# count    7.000000   7.000000
# mean   125.857143  83.285714
# std      2.794553  16.799943
# min    122.000000  56.000000
# 25%    124.000000  73.000000
# 50%    126.000000  87.000000
# 75%    127.500000  97.500000
# max    130.000000  99.000000

# %%
Data_Frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       7 non-null      int64
#  1   Name     7 non-null      object
#  2   Country  7 non-null      object
#  3   Score    7 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 352.0+ bytes

# %%
Data_Frame['Name']
# Out:
# 0    Abigail
# 1        Dor
# 2      Lotem
# 3     Daniel
# 4    Mohamad
# 5        Aya
# 6       Dana
# Name: Name, dtype: object

# %%
Data_Frame[2:6]
# Out:
#     ID     Name Country  Score
# 2  125    Lotem  Israel     98
# 3  126   Daniel     USA     87
# 4  127  Mohamad  Israel     97
# 5  128      Aya  France     79

# %%
Data_Frame.loc[2:5,['ID','Name']]
# Out:
#     ID     Name
# 2  125    Lotem
# 3  126   Daniel
# 4  127  Mohamad
# 5  128      Aya

# %%
Data_Frame.iloc[:,-1].mean()
# Out:
# 83.28571428571429

# %%
Data_Frame.sort_values(by = 'Score', ascending = False ) # False = מגדול לקטן , True = מקטן לגדול
# Out:
#     ID     Name Country  Score
# 0  123  Abigail  Israel     99
# 2  125    Lotem  Israel     98
# 4  127  Mohamad  Israel     97
# 3  126   Daniel     USA     87
# 5  128      Aya  France     79
# 1  122      Dor     USA     67
# 6  130     Dana     NaN     56

# %%
Data_Frame.dropna()
# Out:
#     ID     Name Country  Score
# 0  123  Abigail  Israel     99
# 1  122      Dor     USA     67
# 2  125    Lotem  Israel     98
# 3  126   Daniel     USA     87
# 4  127  Mohamad  Israel     97
# 5  128      Aya  France     79

# %%
Data_Frame.fillna("No Value") # מילוי לבחירתנו
# Out:
#     ID     Name   Country  Score
# 0  123  Abigail    Israel     99
# 1  122      Dor       USA     67
# 2  125    Lotem    Israel     98
# 3  126   Daniel       USA     87
# 4  127  Mohamad    Israel     97
# 5  128      Aya    France     79
# 6  130     Dana  No Value     56
