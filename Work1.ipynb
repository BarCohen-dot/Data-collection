# %% [markdown]
# עבודה ראשונה - חלק א

# %%
import numpy as np #1

# %%
arr = np.array([[6, 8, 4, 2], [7, 5, 3, 1]]) #2

# %%
arr.ndim
# Out:
# 2

# %%
arr.size

# %%
arr.shape
# Out:
# (2, 4)

# %%
np.mean(arr) #3
# Out:
# 4.5

# %%
np.std(arr) #4
# Out:
# 2.29128784747792

# %%
np.sort(arr) #5
# Out:
# array([[2, 4, 6, 8],
#        [1, 3, 5, 7]])

# %%
arr.reshape(1, -1) #6
# Out:
# array([[6, 8, 4, 2, 7, 5, 3, 1]])

# %% [markdown]
# עבודה ראשונה - חלק ב

# %%
array1 = np.random.rand(6, 8) #1
array2 = np.random.rand(6, 8)

# %%
print("Array 1:") #2
print(array1)
print("\nArray 2:")
print(array2)
# Out:
# Array 1:
# [[0.62620293 0.67729093 0.59284191 0.4675173  0.88038744 0.04880517
#   0.08090926 0.58864974]
#  [0.57432302 0.489066   0.1045671  0.53455723 0.17369987 0.23475592
#   0.61812229 0.65251916]
#  [0.40288036 0.73436311 0.47217487 0.97142686 0.94226203 0.4869012
#   0.58620866 0.28020765]
#  [0.84807023 0.09465546 0.07366181 0.57016087 0.57579314 0.88369327
#   0.95779056 0.34065339]
#  [0.78326098 0.66377515 0.21220815 0.05780994 0.50359306 0.53913257
#   0.89479348 0.72999214]
#  [0.87899069 0.93809226 0.53814469 0.21936168 0.87868336 0.54226887
#   0.7414179  0.24495052]]
#
# Array 2:
# [[0.47253709 0.08219914 0.40066685 0.32992461 0.88204399 0.78849213
#   0.99576769 0.45207676]
#  [0.70103504 0.3412123  0.20877092 0.94173556 0.54847842 0.96016808
#   0.81724758 0.19169616]
#  [0.03185229 0.04681424 0.04558784 0.90164359 0.85750252 0.7947865
#   0.78205402 0.33157439]
#  [0.22809319 0.47398431 0.91476877 0.29046935 0.61917689 0.08449103
#   0.51452379 0.9234175 ]
# ...

# %%
sum_arrays = array1 + array2 #3

# %%
multiply_arrays = array1 * array2 #4

# %%
np.savez('collab.npz', array1, array2) #5

# %%
data = np.load('collab.npz')

array1_loaded = data['arr_0']
array2_loaded = data['arr_1']

print("Array 1:", array1_loaded)
print("\nArray 2:", array2_loaded)
# Out:
# Array 1: [[0.62620293 0.67729093 0.59284191 0.4675173  0.88038744 0.04880517
#   0.08090926 0.58864974]
#  [0.57432302 0.489066   0.1045671  0.53455723 0.17369987 0.23475592
#   0.61812229 0.65251916]
#  [0.40288036 0.73436311 0.47217487 0.97142686 0.94226203 0.4869012
#   0.58620866 0.28020765]
#  [0.84807023 0.09465546 0.07366181 0.57016087 0.57579314 0.88369327
#   0.95779056 0.34065339]
#  [0.78326098 0.66377515 0.21220815 0.05780994 0.50359306 0.53913257
#   0.89479348 0.72999214]
#  [0.87899069 0.93809226 0.53814469 0.21936168 0.87868336 0.54226887
#   0.7414179  0.24495052]]
#
# Array 2: [[0.47253709 0.08219914 0.40066685 0.32992461 0.88204399 0.78849213
#   0.99576769 0.45207676]
#  [0.70103504 0.3412123  0.20877092 0.94173556 0.54847842 0.96016808
#   0.81724758 0.19169616]
#  [0.03185229 0.04681424 0.04558784 0.90164359 0.85750252 0.7947865
#   0.78205402 0.33157439]
#  [0.22809319 0.47398431 0.91476877 0.29046935 0.61917689 0.08449103
#   0.51452379 0.9234175 ]
# ...
