# %%
import pandas as pd

# %%
df  = pd.read_json("/content/restaurant_details.json", orient="index") #נכתוב את הנתיב שלו כאן colab-לאחר שהעלנו את הקובץ ל

# %%
df   # נשים לב כי לוקח לקובץ להטען כמה דקות
     # הנתונים ייראו אחרת print בצורת
# Out:
#                                                                                                  imgs  \
# https://www.zomato.com/surat/royal-fast-food-ne...  [https://b.zmtcdn.com/data/pictures/chains/3/1...
# https://www.zomato.com/surat/la-pinoz-pizza-udh...                                                 []
# https://www.zomato.com/surat/shree-khodiyar-kat...                                                 []
# https://www.zomato.com/surat/el-sue%C3%B1o-bake...  [https://b.zmtcdn.com/data/pictures/5/20170555...
# https://www.zomato.com/surat/jay-jalaram-thali-...  [https://b.zmtcdn.com/data/pictures/1/19201471...
# https://www.zomato.com/surat/the-burger-company...  [https://b.zmtcdn.com/data/pictures/4/20197534...
# https://www.zomato.com/surat/radhe-dhokla-rusta...  [https://b.zmtcdn.com/data/pictures/chains/6/1...
# https://www.zomato.com/surat/chandan-bhojnalaya...  [https://b.zmtcdn.com/data/pictures/chains/7/3...
# ...

# %%
print(df.shape)
# Out:
# (41, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, https://www.zomato.com/surat/royal-fast-food-new-textile-market/order to https://www.zomato.com/surat/maakhan-bhog-udhna-gam/order
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imgs                   41 non-null     object
#  1   title                  41 non-null     object
#  2   dining_rating          41 non-null     float64
#  3   dining_total_review    41 non-null     object
#  4   delivery_rating        41 non-null     object
#  5   delivery_total_review  41 non-null     object
#  6   category               41 non-null     object
#  7   address                41 non-null     object
#  8   time                   41 non-null     object
#  9   location               41 non-null     object
#  10  users_review           41 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 4.9+ KB

# %%
print(df.head(10)) # הצגת העשר שורות הראשונות בטבלה
# Out:
#                                                                                                  imgs  \
# https://www.zomato.com/surat/royal-fast-food-ne...  [https://b.zmtcdn.com/data/pictures/chains/3/1...
# https://www.zomato.com/surat/la-pinoz-pizza-udh...                                                 []
# https://www.zomato.com/surat/shree-khodiyar-kat...                                                 []
# https://www.zomato.com/surat/el-sue%C3%B1o-bake...  [https://b.zmtcdn.com/data/pictures/5/20170555...
# https://www.zomato.com/surat/jay-jalaram-thali-...  [https://b.zmtcdn.com/data/pictures/1/19201471...
# https://www.zomato.com/surat/the-burger-company...  [https://b.zmtcdn.com/data/pictures/4/20197534...
# https://www.zomato.com/surat/radhe-dhokla-rusta...  [https://b.zmtcdn.com/data/pictures/chains/6/1...
# https://www.zomato.com/surat/chandan-bhojnalaya...  [https://b.zmtcdn.com/data/pictures/chains/7/3...
# ...

# %%
dining_rating = df[df['dining_rating'] > 3.7] # Dining rating more than 3.7
dining_rating
# Out:
#                                                                                                  imgs  \
# https://www.zomato.com/surat/royal-fast-food-ne...  [https://b.zmtcdn.com/data/pictures/chains/3/1...
# https://www.zomato.com/surat/shree-khodiyar-kat...                                                 []
# https://www.zomato.com/surat/the-burger-company...  [https://b.zmtcdn.com/data/pictures/4/20197534...
# https://www.zomato.com/surat/radhe-dhokla-rusta...  [https://b.zmtcdn.com/data/pictures/chains/6/1...
# https://www.zomato.com/surat/chandan-bhojnalaya...  [https://b.zmtcdn.com/data/pictures/chains/7/3...
# https://www.zomato.com/surat/burger-king-vesu/o...  [https://b.zmtcdn.com/data/pictures/9/3800929/...
# https://www.zomato.com/surat/dilliwale-pahelvan...                                                 []
# https://www.zomato.com/surat/dominos-pizza-athw...  [https://b.zmtcdn.com/data/pictures/1/3800111/...
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def create_wordcloud_from_frequencies(frequencies):
    plt.figure(figsize=(20, 8))
    wc = WordCloud(background_color="white", max_words=1000)
    wc.generate_from_frequencies(frequencies)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# דוגמה לשימוש עם מִילון תדירויות:
dict = df.set_index('title')['dining_rating'].to_dict()
create_wordcloud_from_frequencies(dict)
